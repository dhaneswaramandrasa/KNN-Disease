# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Diagnose of Diseases Prediction Using K Nearest Neighbors
#
# Hello! In this project I would like to predict certain type of diagnosed disease using K Nearest Neighbors.
#
# ## Import Libraries
# **Import pandas,seaborn, and the usual libraries.**

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ## Get the Data

# %%
df = pd.read_csv('wisc_bc_data.csv')

# %% [markdown]
# The data provide us with 31 attributes, strecth from the radius mean until the symmetry worst.

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 569 non-null    int64
#  1   diagnosis          569 non-null    object
#  2   radius_mean        569 non-null    float64
#  3   texture_mean       569 non-null    float64
#  4   perimeter_mean     569 non-null    float64
#  5   area_mean          569 non-null    float64
#  6   smoothness_mean    569 non-null    float64
#  7   compactness_mean   569 non-null    float64
#  8   concavity_mean     569 non-null    float64
#  9   points_mean        569 non-null    float64
#  10  symmetry_mean      569 non-null    float64
#  11  dimension_mean     569 non-null    float64
#  12  radius_se          569 non-null    float64
#  13  texture_se         569 non-null    float64
#  14  perimeter_se       569 non-null    float64
# ...

# %% [markdown]
# **As KNN can only be used with integers, we need to convert the target variable data type:**

# %%
df.diagnosis.nunique()
# Out:
# 2

# %%
df['diagnosis'] =  df['diagnosis'].astype('category').cat.codes

# %%
df.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402          0        12.32         12.39           78.85      464.1
# 1   8910251          0        10.60         18.95           69.28      346.4
# 2    905520          0        11.04         16.83           70.92      373.2
# 3    868871          0        11.28         13.39           73.00      384.8
# 4   9012568          0        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
# ...

# %% [markdown]
# # EDA

# %%
import seaborn as sns

# %%
sns.countplot(df['diagnosis'])

# %%
sns.scatterplot(x = 'radius_mean', y = 'texture_mean', hue='diagnosis', data = df)

# %%
sns.scatterplot(x = 'radius_mean', y = 'area_worst', hue='diagnosis', data = df)

# %%
sns.scatterplot(x = 'texture_mean', y = 'area_worst', hue='diagnosis', data = df)

# %% [markdown]
# # Standardize the Variables
#
# Time to standardize the variables.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(df.drop('diagnosis', axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = scaler.transform(df.drop('diagnosis', axis=1))

# %%
df_trans = pd.DataFrame(scaled_features)

# %%
df_trans.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.454465 -0.513297 -1.605595 -0.540376 -0.542624  0.458285 -0.654413
# 1 -0.171815 -1.001801 -0.079038 -0.934566 -0.877375  0.036986  0.196319
# 2 -0.235899 -0.876835 -0.572377 -0.867014 -0.801153  0.806996 -0.498443
# 3 -0.236192 -0.808671 -1.372888 -0.781338 -0.768161  1.426135  0.175472
# 4 -0.170996  0.301824 -1.414775  0.234000  0.161860 -1.190618 -0.663320
#
#          7         8         9   ...        21        22        23        24  \
# 0 -0.614306 -0.307442  0.538081  ... -0.573451 -1.634499 -0.604391 -0.582718
# 1 -0.312987 -0.580343  0.402996  ... -0.908925 -0.445740 -0.863230 -0.801227
# 2 -0.732448 -0.622129 -0.356400  ... -0.799171  0.124213 -0.814083 -0.719308
# 3 -0.532950 -0.024740 -0.148296  ... -0.900641 -1.613330 -0.915355 -0.785054
# 4 -0.688883 -0.576473 -0.330843  ... -0.014328 -1.619844 -0.082245 -0.108082
#
#          25        26        27        28        29        30
# ...

# %% [markdown]
# # Train Test Split
#
# **Use train_test_split to split the data into a training set and a testing set.**

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_features, df['diagnosis'], test_size = 0.3)

# %% [markdown]
# # Using KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# **Create a KNN model instance with n_neighbors=1**
#
# For beginning, let's try using K value of 1

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# **Fit this KNN model to the training data.**

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#                      weights='uniform')

# %% [markdown]
# # Predictions and Evaluations
# Let's evaluate our KNN model!

# %%
pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, pred))
# Out:
# [[97  4]
#  [ 4 66]]

# %%
print(classification_report(y_test, pred))
# Out:
# precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96       101
#            1       0.94      0.94      0.94        70
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.95      0.95       171
# weighted avg       0.95      0.95      0.95       171

# %% [markdown]
# It generates pretty high accuracy! However is it the best use of K value?

# %% [markdown]
# # Choosing a K Value
# Let's go ahead and use the elbow method to pick a good K Value!

# %%
error_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred = knn.predict(X_test)
    error_rate.append(np.mean(pred != y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue', linestyle='dashed', marker='o',
         markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %% [markdown]
# From the graph above, it looks like that K value of 6 generates the lowest error.

# %% [markdown]
# ## Retrain with new K Value

# %%
knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# [[100   1]
#  [  5  65]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       101
#            1       0.98      0.93      0.96        70
#
#     accuracy                           0.96       171
#    macro avg       0.97      0.96      0.96       171
# weighted avg       0.97      0.96      0.96       171

# %% [markdown]
# As expected, K value of 6 gives us better result!
